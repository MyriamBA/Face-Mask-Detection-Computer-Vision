# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive
# Out:
# /content/drive

# %%
# %cd MyDrive
# Out:
# /content/drive/MyDrive

# %%
# %cd face-mask-detection/
# Out:
# /content/drive/MyDrive/face-mask-detection

# %%
# %cd yolov5/
# Out:
# /content/drive/MyDrive/face-mask-detection/yolov5

# %%
# !pip install -qr requirements.txt  # install dependencies (ignore errors)
import torch
# Out:
#      |████████████████████████████████| 596 kB 17.3 MB/s

# %%
# !python train.py --img 640 --batch 16  --epochs 100 --data coco.yaml --weights yolov5s.pt --cache
# Out:
# ...
# train: weights=yolov5s.pt, cfg=, data=coco.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# Command 'git fetch && git config --get remote.origin.url' timed out after 5 seconds
# YOLOv5 🚀 v6.1-62-g93040ec torch 1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !python detect.py --weights runs/train/exp26/weights/best.pt --img 640 --conf 0.25 --source data/images
display.Image(filename='runs/detect/exp4/without_ymask.jpg', width=600)
# Out:
# detect: weights=['runs/train/exp26/weights/best.pt'], source=data/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-62-g93040ec torch 1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/drive/MyDrive/face-mask-detection/yolov5/data/images/without_ymask.jpg: 352x640 1 without_mask, 1 with_mask, Done. (0.016s)
# Speed: 0.4ms pre-process, 16.4ms inference, 1.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp9
# ---------------------------------------------------------------------------
# ...

# %%
# !python detect.py --weights runs/train/exp26/weights/best.pt --img 640 --conf 0.25 --source me2.mp4
display.Image(filename='runs/detect/exp4/me2.mp4', width=600)
# Out:
# detect: weights=['runs/train/exp26/weights/best.pt'], source=me2.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-62-g93040ec torch 1.11.0+cu113 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/303) /content/drive/MyDrive/face-mask-detection/yolov5/me2.mp4: 384x640 1 without_mask, Done. (0.025s)
# video 1/1 (2/303) /content/drive/MyDrive/face-mask-detection/yolov5/me2.mp4: 384x640 1 without_mask, Done. (0.025s)
# video 1/1 (3/303) /content/drive/MyDrive/face-mask-detection/yolov5/me2.mp4: 384x640 1 without_mask, Done. (0.025s)
# ...

# %%
# !python detect.py --weights runs/train/exp26/weights/best.pt --img 640 --conf 0.25 --source data/images
# Out:
# ...
# detect: weights=['runs/train/exp26/weights/best.pt'], source=data/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-62-g93040ec torch 1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# image 1/4 /content/drive/MyDrive/face-mask-detection/yolov5/data/images/image2.jpg: 640x352 1 mask_weared_incorrect, Done. (0.017s)
# image 2/4 /content/drive/MyDrive/face-mask-detection/yolov5/data/images/image3.jpg: 352x640 1 without_mask, 1 with_mask, Done. (0.017s)
# ...
